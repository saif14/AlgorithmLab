# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizvy-chowdhury/AlgorithmLab/blob/master/Introduction__to_Python_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My Python First Program "Print MY NAME"**
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
print("My Name is Rizvy")
# Out:
# My Name is Rizvy

# %% [markdown]
# # **Variables and Assignment Statements**
#
# ---

# %%
a=14
b=3
print(a+b)
# Out:
# 17

# %%
total = a+b
print(total)
# Out:
# 17

# %%
name = "Rizvy"
name2 = "Tanzila"
print(name , name2)
# Out:
# Rizvy Tanzila

# %% [markdown]
# # **Types**
#
# ---

# %%
R =10.1111
type(R)
# Out:
# float

# %%
type(555555)
# Out:
# int

# %%
type(name)
# Out:
# str

# %% [markdown]
# # **Arithmetic operators**
#
# ---

# %%
 multiplication = 111*10
 print(multiplication)
# Out:
# 1110

# %%
SUM = 10+100
print(SUM)
# Out:
# 110

# %%
SUB = 14-3
print(SUB)
# Out:
# 11

# %%
Exponentiation = 3**5
print(Exponentiation)
# Out:
# 243

# %% [markdown]
# True Division (/) vs. Floor Division (//)

# %%
Division = 55/4
print(Division)
# Out:
# 13.75

# %%
Floor_Division = 7//6
print(Floor_Division)
# Out:
# 1

# %%
remainder = 33%8
print(remainder)
# Out:
# 1

# %% [markdown]
# # **Relational Operators**
#
# ---

# %%
x = 600
y = 6000

# %%
x>y
# Out:
# False

# %%
x<y
# Out:
# True

# %%
x==y
# Out:
# False

# %%
x!=y
# Out:
# True

# %%
x>=y
# Out:
# False

# %%
x<=y
# Out:
# True

# %% [markdown]
# Chaining Comparisons

# %%
x = 3
y = 10

# %%
1 <= x <= 5
# Out:
# False

# %%
1 <= y <= 5
# Out:
# False

# %% [markdown]
# # **Print Function**
#
# ---

# %% [markdown]
# Printing a Comma-Separated List of Items

# %%
print('I', 'am', 'Rizvy!')
# Out:
# I am Rizvy!

# %% [markdown]
# Printing Many Lines of Text with One Statement

# %%
print('I\nam\n\nRizvy!')
# Out:
# I
# am
#
# Rizvy!

# %% [markdown]
# Ignoring a Line Break in a Long String

# %%
print('this is a longer string, so we \
 split it over two lines')
# Out:
# this is a longer string, so we  split it over two lines

# %% [markdown]
# Printing the Value of an Expression

# %%
print('Sum is', 10 + 30)
# Out:
# Sum is 40

# %% [markdown]
# What does the following print statement display?
#
# **print('int(5.2)', 'truncates 5.2 to', int(5.2))**

# %%
print('int(5.2)', 'truncates 5.2 to', int(5.2))
# Out:
# int(5.2) truncates 5.2 to 5

# %% [markdown]
# Including Quotes in Strings

# %%
print('Display "hallow" in quotes')
# Out:
# Display "hallow" in quotes

# %%
print('Display \'Hallow\' in quotes')
# Out:
# Display 'Hallow' in quotes

# %%
print("Display the name O'Brien")
# Out:
# Display the name O'Brien

# %%
print("Display \"Hallow\" in quotes")
# Out:
# Display "Hallow" in quotes

# %% [markdown]
# To avoid using \' and \" inside strings, you can enclose such strings in triple quotes:

# %%
print("""Display "hi" and 'bye' in quotes""")
# Out:
# Display "hi" and 'bye' in quotes

# %% [markdown]
# Multiline Strings

# %%
triple_quoted_string = """This is Rizvy"""

# %%
print(triple_quoted_string)
# Out:
# This is a triple-quoted
# string that spans two lines

# %%
triple_quoted_string
# Out:
# 'This is a triple-quoted\nstring that spans two lines'

# %%
print("""This is Rizvy \
Chowdhury""")
# Out:
# This is Rizvy Chowdhury

# %% [markdown]
# Precision Handling in Python

# %%
a = 3.4536475856

# %%
# using "%" to print value till 2 decimal places  
print ("The value of number till 2 decimal place(using %) is : ",end="") 
print ('%.2f' %a)
# Out:
# The value of number till 2 decimal place(using %) is : 3.45

# %%
# using "%" to print value till 4 decimal places  
print ("The value of number till 2 decimal place(using %) is : ",end="") 
print ('%.4f' %a)
# Out:
# The value of number till 2 decimal place(using %) is : 3.4536

# %% [markdown]
# # **Getting Input from the User**
# The built-in input function requests and obtains user input:

# %%
name = input("What's your name? ")
# Out:
# What's your name? shifat

# %%
print(name)
# Out:
# shifat

# %%
value1 = input('Enter first int: ')
value2 = input('Enter second int: ')
# Out:
# Enter first int: 15
# Enter second int: 15

# %%
total = value1 + value2
print(total)
# Out:
# 1515

# %%
type(total)
# Out:
# str

# %%
total = int(value1) + int(value2) 
print(total)
# Out:
# 70

# %% [markdown]
# Getting an Integer from the User by casting the input format

# %%
another_value = int(input('Enter another integer: '))
# Out:
# Enter another integer: 10

# %%
print(another_value)
# Out:
# 10

# %% [markdown]
# **Taking multiple input from the user**

# %%
a, b = input().split()
# Out:
# 10 20

# %%
print(a , b)
# Out:
# 10 20

# %%
print(type(a))
# Out:
# <class 'str'>

# %% [markdown]
# # Solving Problem
#
# **Determining the Minimum and Maximum with Built-In Functions min and max**
#
#
# ---

# %%
number1 = int(input('Enter first integer: '))
number2 = int(input('Enter second integer: '))
number3 = int(input('Enter third integer: '))
# Out:
# Enter first integer: 20
# Enter second integer: 50
# Enter third integer: 100

# %%
min(number1,number2,number3)
# Out:
# 20

# %%
max(number1,number2,number3)
# Out:
# 100

# %% [markdown]
# #***Exercises***
#
# ---
#
#
#
# **Create the variables x = 2 and y = 3, then determine what
# each of the following statements displays:**
#
# *  print('x =', x)
# *  print('Value of', x, '+', x, 'is', (x + x))
# *  print('x =')
# *  print((x + y), '=', (y + x))
#
#
# ---

# %%
x = 2
y = 3
print('x =', x)
# Out:
# x = 2

# %%
print('Value of', x, '+', x, 'is', (x + x))
# Out:
# Value of 2 + 2 is 4

# %%
print('x =')
# Out:
# x =

# %%
print((x + y), '=', (y + x))
# Out:
# 5 = 5

# %% [markdown]
# IF statement

# %%
grade = 30
if grade<=40:
  print("failed")
# Out:
# failed

# %% [markdown]
# If else statement

# %%
grade = 41
if grade>=40:
  print("passed")
else:
  print("fail")
# Out:
# passed

# %% [markdown]
# Conditional expression

# %%
result = ('Passed' if grade >= 40 else 'Failed')

# %%
print(result)
# Out:
# Passed

# %%
grade = 40

if grade >= 90:
    print('A')
elif grade >= 80:
    print('B')
elif grade >= 70:
    print('C')
elif grade >= 60:
    print('D')
else:
    print('F')
# Out:
# F

# %% [markdown]
# While Statement

# %%
number = 5

while (number<10):
  print(number, end=" ") #print in same line with space using end =" "
  number+=1
# Out:
# 5 6 7 8 9

# %% [markdown]
# For statement

# %%
for character in "Rizvy":
  print(character, end=" ")
# Out:
# R i z v y
